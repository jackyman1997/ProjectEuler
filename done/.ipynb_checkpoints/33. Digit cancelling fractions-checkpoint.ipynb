# %% [markdown]
# ## <a href='https://projecteuler.net/problem=33'>33. Digit cancelling fractions</a>
# The fraction $\frac{49}{98}$ is a curious fraction, as an inexperienced mathematician in <a href='https://en.wikipedia.org/wiki/Anomalous_cancellation'>attempting to simplify</a> it may incorrectly believe that $\frac{49}{98}$ = $\frac{4}{8}$, which is correct, is obtained by cancelling the 9s.
#
# We shall consider fractions like, $\frac{30}{50}$ = $\frac{3}{5}$, to be trivial examples.
#
# There are exactly four non-trivial examples of this type of fraction, less than one in value, and containing two digits in the numerator and denominator.
#
# If the product of these four fractions is given in its lowest common terms, find the value of the denominator.
# ___

# %% [markdown]
# by hand:
#
# 1. listing all possible fractions, starts with x1/1y $\frac{x1}{1y}$:
# for x is not 1 or 0, x = 2, but then 21 > 12 so nah
#
#
# 2. x2/2y $\frac{x2}{2y}$:
# the max of x is 2, but 2 is not good coz 22 = '2y' times something between [0,1]
# so 12/2y --> '2y' = any number that share the factors of 12:{1,2,3,4,6,12}
# '2y' = 21,22,24,26,28
# 12/21 = 4/7 -> 1/1 nah ; 12/22 = 6/11 -> 1/2 nah ; 12/24 = 1/2 -> 1/4 nah ; 12/26 = 6/13 -> 1/6 nah ; 12/28 = 3/7 -> 1/8 nah
#
#
# 3. x3/3y $\frac{x3}{3y}$:
# same logic, x<3 so try 1 and 2
# 2 is no good, then x=1
# so 13/3y --> '3y' = any number that share the factors of 13:{1,13}
# '3y' = 39
# 13/39 = 1/3 -> 1/9 nah
#
#
# 4. x4/4y $\frac{x4}{4y}$:
# same logic, x<4 so try 1 and 2
#  - if x=1:
# so 14/4y --> '4y' = any number that share the factors of 14:{1,2,7,14}
# '4y' = 42,44,46,48,49
# 14/42 = 1/3 -> 1/2 nah ; 14/44 = 7/11 -> 1/4 nah ; 14/46 = 7/23 -> 1/6 nah ; 14/48 = 7/24 -> 1/8 nah ; 14/49 = 2/7 -> 1/9 nah
#  - if x=2:
# so 24/4y --> '4y' = any number that share the factors of 24:{1,2,3,4,6,8,12,24}
# '4y' = 44,46,48
# 24/44 = 6/11 -> 2/4 nah ; 24/46 = 12/23 -> 2/6 nah ; 24/48 = 1/2 -> 2/8 nah
#
#
# 5. x5/5y $\frac{x5}{5y}$:
# same logic, x<5 so try 1 and 2
#  - if x=1:
# so 15/5y --> '5y' = any number that share the factors of 15:{1,3,5,15}
# '5y' = 55
# 15/55 = 3/11 -> 1/5 nah
#  - if x=2:
# so 25/5y --> '5y' = any number that share the factors of 25:{1,5,25}
# '5y' = 55
# 25/55 = 5/11 -> 2/5 nah
#
#
# 6. x6/6y $\frac{x6}{6y}$:
# same logic, x<6 so try 1,2,3
#  - if x=1:
# so 16/6y --> '6y' = any number that share the factors of 16:{1,2,4,8,16}
# '6y' = 62,64,66,68
# 16/62 =/= 1/2 nah ; 16/64 = 1/4 -> 1/4 __[1]__ ; 16/66 = 8/33 -> 1/6 nah ; 16/68 = 4/17 -> 1/8 nah
#  - if x=2:
# so 26/6y --> '6y' = any number that share the factors of 26:{1,2,13,26}
# '6y' = 64,65,66,68
# 26/64 =/= 1/2 nah ; 26/65 = 2/5 -> 2/5 __[2]__ ; 26/66 = 13/33 -> 2/6 nah ; 26/68 = 13/34 -> 2/8 nah
#  - if x=3:
# so 36/6y --> '6y' = any number that share the factors of 36:{1,2,3,4,6,9,12,18,36}
# '6y' = 64,66,68,69
# 36/64 =/= 3/4 nah ; 36/66 =/= 3/6 nah ; 36/68 =/= 3/8 nah ; 36/69 =/= 3/9 nah
#
#
# 7. x7/7y $\frac{x7}{7y}$:
# same logic, x<7 so try 1,2,3
#  - if x=1:
# so 17/7y --> '7y' = any number that share the factors of 17:{1,17}
# '7y' = none --> nah
#  - if x=2:
# so 27/7y --> '7y' = any number that share the factors of 27:{1,3,9,27}
# '7y' = 75,78
# 27/75 = 9/25 -> 2/5 nah ; 27/78 - 9/26 nah
#  - if x=3:
# so 37/7y --> '7y' = any number that share the factors of 37:{1,37}
# '7y' = 74
# 37/74 = 1/2 -> 3/4 nah
#
#
# 8. x8/8y $\frac{x8}{8y}$:
# same logic, x<8 so try 1,2,3,4
#  - if x=1:
# so 18/8y --> '8y' = any number that share the factors of 18:{1,2,3,6,9,18}
# '8y' = 82,84,86,87,88
# 18/82 =/= 1/2 nah ; 18/84 = 3/14 nah ; 18/86 = 2/43 nah ; 18/87 = 6/29 nah ; 18/88 = 2/11 nah
#  - if x=2:
# so 28/8y --> '8y' = any number that share the factors of 28:{1,2,4,7,14,28}
# '8y' = 84,86,88
# 28/84 =/= 2/4 nah ; 28/86 = 14/43 nah ; 28/88 = 7/22 nah
#  - if x=3:
# so 38/8y --> '8y' = any number that share the factors of 38:{1,2,19,38}
# '8y' = 84,86,88
# 38/84 =/= 3/4 nah ; 38/86 = 3/6 nah ; 38/88 = 19/44 nah
#  - if x=4:
# so 48/8y --> '8y' = any number that share the factors of 48:{1,2,3,4,6,8,12,16,24,48}
# '8y' = 85,86,88
# 48/85 =/= 4/5 nah ; 48/86 = 4/6 nah ; 48/88 = 6/11 nah
#
#
# 9. x9/9y $\frac{x9}{9y}$:
# same logic, x<9 so try 1,2,3,4
#  - if x=1:
# so 19/9y --> '9y' = any number that share the factors of 19:{1,19}
# '9y' = 95
# 19/85 = 1/5 -> 1/5 __[3]__
#  - if x=2:
# so 29/9y --> '9y' = any number that share the factors of 29:{1,29}
# '9y' = none --> nah
#  - if x=3:
# so 39/9y --> '9y' = any number that share the factors of 39:{1,3,13,39}
# '9y' = 96,99
# 39/96 =/= 3/6 nah ; 39/99 = 13/33 nah
#  - if x=4:
# so 49/9y --> '9y' = any number that share the factors of 49:{1,7,49}
# '9y' = 98
# 49/98 = 4/8 -> 4/8 __[4]__
#
#
# got $\frac{16}{64}$ , $\frac{26}{65}$ , $\frac{19}{95}$ , $\frac{49}{98}$
# gives the product of $\frac{387296}{38729600} = \frac{1}{100}$

# %%
def gcd(a: int, b: int) -> int:
    '''
    recusion
    '''
    # base case with 0 
    if a == 0 or b == 0:
        return max(a, b)
    if a < b:
        a, b = b, a
    if a%b == 0:
        return b
    else:
        return gcd(b, a%b)
        
def gcd(a: int, b: int) -> int:
    '''
    iterative
    '''
    a, b = min(a, b), max(a, b)
    while b%a != 0:
        a , b = b%a , a
    return a

def ReducedFraction(norminator: int, denominator: int) -> tuple:
    '''
    simplify fraction in the form of p/q
    '''
    try:
        p, q = int(norminator), int(denominator)
        common_divisor = gcd(p, q)
        p, q = p//common_divisor, q//common_divisor
        return (p, q)
    except (ZeroDivisionError, NameError) as error:
        print('bruh check your input, only int input and no 0 in denominator!')
        pass

# %%
def q33():
    # storage
    magics = []
    # loop, as 'containing two digits' so max is 100
    for bottom in range(1, 100):
        # less than one in value' so top can never > bottom
        for top in range(1, bottom):
            # remove cases that not fit here (single digit, repeat digit, with 0)
            # using set
            top_digit_set = set( str(top) )
            bottom_digit_set = set( str(bottom) )
            if (
                ('0' not in top_digit_set|bottom_digit_set) and 
                (len(top_digit_set) > 1) and 
                (len(bottom_digit_set) > 1)
            ):
                # check cancelling (magic)
                repeat_set = top_digit_set&bottom_digit_set
                # if share a digit
                if repeat_set:
                    # obtain the element in set, there are other ways
                    repeat = repeat_set.pop()
                    # replace to repeat digit string by '', just like the cancelling magic
                    top_cancelled = str(top).replace(repeat, '')
                    bottom_cancelled = str(bottom).replace(repeat, '')
                    # do Reduced Fraction again, to ensure that is also in reduced form
                    magic = ReducedFraction(int(top_cancelled), int(bottom_cancelled))
                    # actual arithmetics on Reduced Fraction
                    arithmetics_reduced = ReducedFraction(top, bottom)
                    # if both are the same
                    if magic == arithmetics_reduced:
                        magics.append((top, bottom))

    # multply all magic fractions, ReducedFraction() it and print it denominator
    product_top = 1
    product_bottom = 1
    for i, j in magics:
        product_top *= i
        product_bottom *= j

    return print(magics, \
                 '\nthe denominator of the product of those fractions in reduced form is: %i'% \
                 ReducedFraction(product_top, product_bottom)[1])

# %%
# %%timeit -n 1 -r 1
q33()
# Out:
# [(16, 64), (26, 65), (19, 95), (49, 98)]
# the denominator of the product of those fractions in reduced form is: 100
# 7.51 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)
